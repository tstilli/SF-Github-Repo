# %%
# !pip install Office365-REST-Python-Client
# !pip install office365
# Out:
# ^C
# Collecting Office365-REST-Python-Client
#   Using cached Office365_REST_Python_Client-2.3.16-py3-none-any.whl (716 kB)
# Requirement already satisfied: requests in c:\users\tsingleton\appdata\local\programs\python\python310\lib\site-packages (from Office365-REST-Python-Client) (2.21.0)
# Requirement already satisfied: pytz in c:\users\tsingleton\appdata\local\programs\python\python310\lib\site-packages (from Office365-REST-Python-Client) (2022.1)
# Requirement already satisfied: msal in c:\users\tsingleton\appdata\local\programs\python\python310\lib\site-packages (from Office365-REST-Python-Client) (1.21.0)
# Requirement already satisfied: cryptography<41,>=0.6 in c:\users\tsingleton\appdata\local\programs\python\python310\lib\site-packages (from msal->Office365-REST-Python-Client) (37.0.4)
# Requirement already satisfied: PyJWT[crypto]<3,>=1.0.0 in c:\users\tsingleton\appdata\local\programs\python\python310\lib\site-packages (from msal->Office365-REST-Python-Client) (2.6.0)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\tsingleton\appdata\local\programs\python\python310\lib\site-packages (from requests->Office365-REST-Python-Client) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\tsingleton\appdata\local\programs\python\python310\lib\site-packages (from requests->Office365-REST-Python-Client) (2021.10.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\tsingleton\appdata\local\programs\python\python310\lib\site-packages (from requests->Office365-REST-Python-Client) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in c:\users\tsingleton\appdata\local\programs\python\python310\lib\site-packages (from requests->Office365-REST-Python-Client) (1.24.3)
# Requirement already satisfied: cffi>=1.12 in c:\users\tsingleton\appdata\roaming\python\python310\site-packages (from cryptography<41,>=0.6->msal->Office365-REST-Python-Client) (1.15.0)
# Requirement already satisfied: pycparser in c:\users\tsingleton\appdata\roaming\python\python310\site-packages (from cffi>=1.12->cryptography<41,>=0.6->msal->Office365-REST-Python-Client) (2.21)
# Installing collected packages: Office365-REST-Python-Client
# Successfully installed Office365-REST-Python-Client-2.3.16
# WARNING: Ignoring invalid distribution -ip (c:\users\tsingleton\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\tsingleton\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\tsingleton\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\tsingleton\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\tsingleton\appdata\local\programs\python\python310\lib\site-packages)
# Collecting office365
# WARNING: Ignoring invalid distribution -ip (c:\users\tsingleton\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\tsingleton\appdata\local\programs\python\python310\lib\site-packages)
#   DEPRECATION: pyperclip is being installed using the legacy 'setup.py install' method, because it does not have a 'pyproject.toml' and the 'wheel' package is not installed. pip 23.1 will enforce this behaviour change. A possible replacement is to enable the '--use-pep517' option. Discussion can be found at https://github.com/pypa/pip/issues/8559
#   DEPRECATION: cursor is being installed using the legacy 'setup.py install' method, because it does not have a 'pyproject.toml' and the 'wheel' package is not installed. pip 23.1 will enforce this behaviour change. A possible replacement is to enable the '--use-pep517' option. Discussion can be found at https://github.com/pypa/pip/issues/8559
#   DEPRECATION: olefile is being installed using the legacy 'setup.py install' method, because it does not have a 'pyproject.toml' and the 'wheel' package is not installed. pip 23.1 will enforce this behaviour change. A possible replacement is to enable the '--use-pep517' option. Discussion can be found at https://github.com/pypa/pip/issues/8559
#   DEPRECATION: clipboard is being installed using the legacy 'setup.py install' method, because it does not have a 'pyproject.toml' and the 'wheel' package is not installed. pip 23.1 will enforce this behaviour change. A possible replacement is to enable the '--use-pep517' option. Discussion can be found at https://github.com/pypa/pip/issues/8559
#   DEPRECATION: case-conversion is being installed using the legacy 'setup.py install' method, because it does not have a 'pyproject.toml' and the 'wheel' package is not installed. pip 23.1 will enforce this behaviour change. A possible replacement is to enable the '--use-pep517' option. Discussion can be found at https://github.com/pypa/pip/issues/8559
#   DEPRECATION: moviepy is being installed using the legacy 'setup.py install' method, because it does not have a 'pyproject.toml' and the 'wheel' package is not installed. pip 23.1 will enforce this behaviour change. A possible replacement is to enable the '--use-pep517' option. Discussion can be found at https://github.com/pypa/pip/issues/8559
#   DEPRECATION: bs4 is being installed using the legacy 'setup.py install' method, because it does not have a 'pyproject.toml' and the 'wheel' package is not installed. pip 23.1 will enforce this behaviour change. A possible replacement is to enable the '--use-pep517' option. Discussion can be found at https://github.com/pypa/pip/issues/8559
# WARNING: Ignoring invalid distribution -ip (c:\users\tsingleton\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\tsingleton\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\tsingleton\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\tsingleton\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\tsingleton\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\tsingleton\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\tsingleton\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\tsingleton\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\tsingleton\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\tsingleton\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\tsingleton\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\tsingleton\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\tsingleton\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\tsingleton\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\tsingleton\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\tsingleton\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\tsingleton\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\tsingleton\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\tsingleton\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\tsingleton\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\tsingleton\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\tsingleton\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\tsingleton\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\tsingleton\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\tsingleton\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\tsingleton\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\tsingleton\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\tsingleton\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\tsingleton\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\tsingleton\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\tsingleton\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\tsingleton\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\tsingleton\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\tsingleton\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\tsingleton\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\tsingleton\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\tsingleton\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\tsingleton\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\tsingleton\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\tsingleton\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\tsingleton\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\tsingleton\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\tsingleton\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\tsingleton\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\tsingleton\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\tsingleton\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\tsingleton\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\tsingleton\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\tsingleton\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\tsingleton\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\tsingleton\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\tsingleton\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\tsingleton\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\tsingleton\appdata\local\programs\python\python310\lib\site-packages)
#   Using cached office365-0.3.15-py3-none-any.whl (32 kB)
# Collecting O365
#   Using cached O365-2.0.26-py3-none-any.whl (163 kB)
# Collecting azure-storage-blob
#   Using cached azure_storage_blob-12.14.1-py3-none-any.whl (383 kB)
# Collecting pysubtypes
#   Using cached pysubtypes-0.3.18-py3-none-any.whl (31 kB)
# Collecting pymiscutils
#   Using cached pymiscutils-0.3.14-py3-none-any.whl (14 kB)
# Collecting maybe-else
#   Using cached maybe_else-0.2.1-py3-none-any.whl (5.5 kB)
# Collecting pathmagic
#   Using cached pathmagic-0.3.14-py3-none-any.whl (21 kB)
# Collecting pyiotools
#   Using cached pyiotools-0.3.18-py3-none-any.whl (47 kB)
# Requirement already satisfied: cryptography>=2.1.4 in c:\users\tsingleton\appdata\local\programs\python\python310\lib\site-packages (from azure-storage-blob->office365) (37.0.4)
# Collecting azure-core<2.0.0,>=1.24.2
#   Using cached azure_core-1.26.3-py3-none-any.whl (174 kB)
# Collecting msrest>=0.7.1
#   Using cached msrest-0.7.1-py3-none-any.whl (85 kB)
# Collecting tzlocal>=4.0
#   Using cached tzlocal-4.2-py3-none-any.whl (19 kB)
# Requirement already satisfied: requests>=2.18.0 in c:\users\tsingleton\appdata\local\programs\python\python310\lib\site-packages (from O365->office365) (2.21.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\tsingleton\appdata\roaming\python\python310\site-packages (from O365->office365) (2.8.2)
# Requirement already satisfied: pytz>=2018.5 in c:\users\tsingleton\appdata\local\programs\python\python310\lib\site-packages (from O365->office365) (2022.1)
# Collecting beautifulsoup4>=4.0.0
#   Using cached beautifulsoup4-4.11.2-py3-none-any.whl (129 kB)
# Requirement already satisfied: requests-oauthlib>=1.2.0 in c:\users\tsingleton\appdata\local\programs\python\python310\lib\site-packages (from O365->office365) (1.3.1)
# Requirement already satisfied: stringcase>=1.2.0 in c:\users\tsingleton\appdata\local\programs\python\python310\lib\site-packages (from O365->office365) (1.2.0)
# Collecting pydub
#   Using cached pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Collecting bs4
#   Using cached bs4-0.0.1.tar.gz (1.1 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: python-docx in c:\users\tsingleton\appdata\local\programs\python\python310\lib\site-packages (from pathmagic->office365) (0.8.11)
# Requirement already satisfied: PyPDF2 in c:\users\tsingleton\appdata\local\programs\python\python310\lib\site-packages (from pathmagic->office365) (1.27.1)
# Requirement already satisfied: Pillow in c:\users\tsingleton\appdata\local\programs\python\python310\lib\site-packages (from pathmagic->office365) (9.0.0)
# Requirement already satisfied: pandas in c:\users\tsingleton\appdata\local\programs\python\python310\lib\site-packages (from pathmagic->office365) (1.3.5)
# Collecting moviepy
#   Using cached moviepy-1.0.3.tar.gz (388 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting dill
#   Using cached dill-0.3.6-py3-none-any.whl (110 kB)
# Collecting appdirs
#   Using cached appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: Send2Trash in c:\users\tsingleton\appdata\roaming\python\python310\site-packages (from pathmagic->office365) (1.8.0)
# Requirement already satisfied: simplejson in c:\users\tsingleton\appdata\local\programs\python\python310\lib\site-packages (from pathmagic->office365) (3.18.0)
# Collecting typepy
#   Using cached typepy-1.3.0-py3-none-any.whl (31 kB)
# Collecting cursor
#   Using cached cursor-1.3.5.tar.gz (15 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: colorama in c:\users\tsingleton\appdata\roaming\python\python310\site-packages (from pyiotools->office365) (0.4.4)
# Collecting PyQt5
#   Using cached PyQt5-5.15.9-cp37-abi3-win_amd64.whl (6.8 MB)
# Collecting infi.systray
#   Using cached infi.systray-0.1.12-py3-none-any.whl (9.2 kB)
# Collecting readchar
#   Using cached readchar-4.0.3-py3-none-any.whl (8.4 kB)
# Collecting APScheduler
#   Using cached APScheduler-3.10.0-py3-none-any.whl (59 kB)
# Collecting pyinstrument
#   Using cached pyinstrument-4.4.0-cp310-cp310-win_amd64.whl (105 kB)
# Requirement already satisfied: numpy in c:\users\tsingleton\appdata\local\programs\python\python310\lib\site-packages (from pymiscutils->office365) (1.22.3)
# Collecting gender-guesser
#   Using cached gender_guesser-0.4.0-py2.py3-none-any.whl (379 kB)
# Collecting case-conversion
#   Using cached case_conversion-2.1.0.tar.gz (4.4 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting fuzzywuzzy
#   Using cached fuzzywuzzy-0.18.0-py2.py3-none-any.whl (18 kB)
# Collecting colour
#   Using cached colour-0.1.5-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: xlsxwriter in c:\users\tsingleton\appdata\local\programs\python\python310\lib\site-packages (from pysubtypes->office365) (3.0.3)
# Collecting aenum
#   Using cached aenum-3.1.11-py3-none-any.whl (131 kB)
# Collecting html-text
#   Using cached html_text-0.5.2-py2.py3-none-any.whl (7.5 kB)
# Collecting regex
#   Using cached regex-2022.10.31-cp310-cp310-win_amd64.whl (267 kB)
# Collecting parsedatetime
#   Using cached parsedatetime-2.6-py3-none-any.whl (42 kB)
# Collecting prettierfier
#   Using cached prettierfier-1.0.3-py3-none-any.whl (5.3 kB)
# Collecting msoffcrypto-tool
#   Using cached msoffcrypto_tool-5.0.0-py3-none-any.whl (33 kB)
# Collecting tabulate
#   Using cached tabulate-0.9.0-py3-none-any.whl (35 kB)
# Collecting inflect
#   Using cached inflect-6.0.2-py3-none-any.whl (34 kB)
# Requirement already satisfied: urllib3 in c:\users\tsingleton\appdata\local\programs\python\python310\lib\site-packages (from pysubtypes->office365) (1.24.3)
# Collecting clipboard
#   Using cached clipboard-0.0.4.tar.gz (1.7 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: six>=1.11.0 in c:\users\tsingleton\appdata\roaming\python\python310\site-packages (from azure-core<2.0.0,>=1.24.2->azure-storage-blob->office365) (1.16.0)
# Collecting typing-extensions>=4.0.1
#   Using cached typing_extensions-4.5.0-py3-none-any.whl (27 kB)
# Collecting soupsieve>1.2
#   Using cached soupsieve-2.4-py3-none-any.whl (37 kB)
# Requirement already satisfied: cffi>=1.12 in c:\users\tsingleton\appdata\roaming\python\python310\site-packages (from cryptography>=2.1.4->azure-storage-blob->office365) (1.15.0)
# Collecting isodate>=0.6.0
#   Using cached isodate-0.6.1-py2.py3-none-any.whl (41 kB)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\tsingleton\appdata\local\programs\python\python310\lib\site-packages (from msrest>=0.7.1->azure-storage-blob->office365) (2021.10.8)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\tsingleton\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.18.0->O365->office365) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\tsingleton\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.18.0->O365->office365) (3.0.4)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\tsingleton\appdata\local\programs\python\python310\lib\site-packages (from requests-oauthlib>=1.2.0->O365->office365) (3.2.0)
# Collecting pytz-deprecation-shim
#   Using cached pytz_deprecation_shim-0.1.0.post0-py2.py3-none-any.whl (15 kB)
# Collecting tzdata
#   Using cached tzdata-2022.7-py2.py3-none-any.whl (340 kB)
# Requirement already satisfied: setuptools>=0.7 in c:\users\tsingleton\appdata\roaming\python\python310\site-packages (from APScheduler->pyiotools->office365) (62.3.2)
# Collecting pyperclip>=1.3
#   Using cached pyperclip-1.8.2.tar.gz (20 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: lxml in c:\users\tsingleton\appdata\local\programs\python\python310\lib\site-packages (from html-text->pysubtypes->office365) (4.8.0)
# Collecting pydantic>=1.9.1
#   Downloading pydantic-1.10.5-cp310-cp310-win_amd64.whl (2.1 MB)
#      ---------------------------------------- 2.1/2.1 MB 15.0 MB/s eta 0:00:00
# Collecting decorator<5.0,>=4.0.2
#   Using cached decorator-4.4.2-py2.py3-none-any.whl (9.2 kB)
# Collecting tqdm<5.0,>=4.11.2
#   Using cached tqdm-4.64.1-py2.py3-none-any.whl (78 kB)
# Collecting proglog<=1.0.0
#   Using cached proglog-0.1.10-py3-none-any.whl (6.1 kB)
# Collecting imageio<3.0,>=2.5
#   Using cached imageio-2.25.1-py3-none-any.whl (3.4 MB)
# Collecting imageio_ffmpeg>=0.2.0
#   Using cached imageio_ffmpeg-0.4.8-py3-none-win_amd64.whl (22.6 MB)
# Collecting olefile>=0.45
#   Using cached olefile-0.46.zip (112 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: PyQt5-Qt5>=5.15.2 in c:\users\tsingleton\appdata\local\programs\python\python310\lib\site-packages (from PyQt5->pyiotools->office365) (5.15.2)
# Collecting PyQt5-sip<13,>=12.11
#   Using cached PyQt5_sip-12.11.1-cp310-cp310-win_amd64.whl (78 kB)
# Collecting mbstrdecoder<2,>=1.0.0
#   Using cached mbstrdecoder-1.1.2-py3-none-any.whl (7.7 kB)
# Requirement already satisfied: pycparser in c:\users\tsingleton\appdata\roaming\python\python310\site-packages (from cffi>=1.12->cryptography>=2.1.4->azure-storage-blob->office365) (2.21)
# Installing collected packages: pyperclip, pydub, prettierfier, parsedatetime, maybe-else, gender-guesser, fuzzywuzzy, cursor, colour, appdirs, aenum, tzdata, typing-extensions, tqdm, tabulate, soupsieve, regex, readchar, PyQt5-sip, pyinstrument, olefile, mbstrdecoder, isodate, infi.systray, imageio_ffmpeg, imageio, html-text, dill, decorator, clipboard, typepy, pytz-deprecation-shim, PyQt5, pydantic, proglog, case-conversion, beautifulsoup4, azure-core, tzlocal, msrest, msoffcrypto-tool, moviepy, inflect, bs4, pysubtypes, O365, azure-storage-blob, APScheduler, pathmagic, pymiscutils, pyiotools, office365
#   Running setup.py install for pyperclip: started
#   Running setup.py install for pyperclip: finished with status 'done'
#   Running setup.py install for cursor: started
#   Running setup.py install for cursor: finished with status 'done'
#   Running setup.py install for olefile: started
#   Running setup.py install for olefile: finished with status 'done'
#   Attempting uninstall: decorator
#     Found existing installation: decorator 5.1.1
#     Uninstalling decorator-5.1.1:
#       Successfully uninstalled decorator-5.1.1
#   Running setup.py install for clipboard: started
#   Running setup.py install for clipboard: finished with status 'done'
#   Running setup.py install for case-conversion: started
#   Running setup.py install for case-conversion: finished with status 'done'
#   Running setup.py install for moviepy: started
#   Running setup.py install for moviepy: finished with status 'done'
#   Running setup.py install for bs4: started
#   Running setup.py install for bs4: finished with status 'done'
# Successfully installed APScheduler-3.10.0 O365-2.0.26 PyQt5-5.15.9 PyQt5-sip-12.11.1 aenum-3.1.11 appdirs-1.4.4 azure-core-1.26.3 azure-storage-blob-12.14.1 beautifulsoup4-4.11.2 bs4-0.0.1 case-conversion-2.1.0 clipboard-0.0.4 colour-0.1.5 cursor-1.3.5 decorator-5.1.1 dill-0.3.6 fuzzywuzzy-0.18.0 gender-guesser-0.4.0 html-text-0.5.2 imageio-2.25.1 imageio_ffmpeg-0.4.8 infi.systray-0.1.12 inflect-6.0.2 isodate-0.6.1 maybe-else-0.2.1 mbstrdecoder-1.1.2 moviepy-1.0.3 msoffcrypto-tool-5.0.0 msrest-0.7.1 office365-0.3.15 olefile-0.46 parsedatetime-2.6 pathmagic-0.3.14 prettierfier-1.0.3 proglog-0.1.10 pydantic-1.10.5 pydub-0.25.1 pyinstrument-4.4.0 pyiotools-0.3.18 pymiscutils-0.3.14 pyperclip-1.8.2 pysubtypes-0.3.18 pytz-deprecation-shim-0.1.0.post0 readchar-4.0.3 regex-2022.10.31 soupsieve-2.4 tabulate-0.9.0 tqdm-4.64.1 typepy-1.3.0 typing-extensions-4.5.0 tzdata-2022.7 tzlocal-4.2

# %%
from office365.sharepoint.client_context import ClientContext
from office365.runtime.auth.user_credential import UserCredential
from office365.sharepoint.files.file import File
