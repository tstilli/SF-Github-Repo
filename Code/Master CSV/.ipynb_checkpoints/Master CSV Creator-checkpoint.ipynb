# %%
import pandas as pd
import numpy as np
import os

# %%
#with open('Master Sheets/Master Fuel.csv', 'x') as f:
#    f.close()

# %%
sheets = ['Database User', 'Database ZEV', 'Database BYD', 'Database RYD', 'Database Fuel']
#path = os.getcwd()+'/'+'Forms'
path = 'C:\\Users\\tsingleton\\Desktop\\CALSTART\\2. Sus Fleets\\4. Version Control Github\\SF-Github-Repo\\Report\\Fleet Enrollment Forms'

# %%
#work on avoiding rewritting same data every time program is executed.
#can try checking for fleet name in Master User csv to see if file needs to be writen to csv as well

# %%
for file in os.listdir(path):
    print(file)
    #for the current file create a separate dataframe for each database sheet and store it in a list
    for sheet in sheets:
        if sheet == 'Database User':
            df = pd.read_excel(path+'/'+file, sheet_name = sheet)
            df.to_csv('Master Sheets/Master User.csv', index = None, header = None, sep = ' ', mode = 'a')
            
        if sheet == 'Database ZEV':
            df = pd.read_excel(path+'/'+file, sheet_name = sheet)
            df['fleet'] = file.split(' Sustainable ')[0]
            df.to_csv('Master Sheets/Master ZEV.csv', index = None, header = None, sep = ' ', mode = 'a')
            
        if sheet == 'Database BYD':
            df = pd.read_excel(path+'/'+file, sheet_name = sheet)
            df['fleet'] = file.split(' Sustainable ')[0]
            df.to_csv('Master Sheets/Master BYD.csv', index = None, header = None, sep = ' ', mode = 'a')
            
        if sheet == 'Database RYD':
            df = pd.read_excel(path+'/'+file, sheet_name = sheet)
            df['fleet'] = file.split(' Sustainable ')[0]
            df.to_csv('Master Sheets/Master RYD.csv', index = None, header = None, sep = ' ', mode = 'a')
            
        if sheet == 'Database Fuel':
            df = pd.read_excel(path+'/'+file, sheet_name = sheet)
            df['fleet'] = file.split(' Sustainable ')[0]
            df.to_csv('Master Sheets/Master Fuel.csv', index = None, header = None, sep = ' ', mode = 'a')
# Out:
# Black Solid Sustainable Fleets Benchmark Form - Ordered Vehicles.xlsx
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [16], in <cell line: 1>()
#       5 if sheet == 'Database User':
#       6     df = pd.read_excel(path+'/'+file, sheet_name = sheet)
# ----> 7     df.to_csv('Master Sheets/Master User.csv', index = None, header = None, sep = ' ', mode = 'a')
#       9 if sheet == 'Database ZEV':
#      10     df = pd.read_excel(path+'/'+file, sheet_name = sheet)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:3466, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3455 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3457 formatter = DataFrameFormatter(
#    3458     frame=df,
#    3459     header=header,
#    (...)
#    3463     decimal=decimal,
#    3464 )
# -> 3466 return DataFrameRenderer(formatter).to_csv(
#    3467     path_or_buf,
#    3468     line_terminator=line_terminator,
#    3469     sep=sep,
#    3470     encoding=encoding,
#    3471     errors=errors,
#    3472     compression=compression,
#    3473     quoting=quoting,
#    3474     columns=columns,
#    3475     index_label=index_label,
#    3476     mode=mode,
#    3477     chunksize=chunksize,
#    3478     quotechar=quotechar,
#    3479     date_format=date_format,
#    3480     doublequote=doublequote,
#    3481     escapechar=escapechar,
#    3482     storage_options=storage_options,
#    3483 )
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\formats\format.py:1086, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1083 else:
#    1084     created_buffer = False
# -> 1086 csv_formatter = CSVFormatter(
#    1087     path_or_buf=path_or_buf,
#    1088     line_terminator=line_terminator,
#    1089     sep=sep,
#    1090     encoding=encoding,
#    1091     errors=errors,
#    1092     compression=compression,
#    1093     quoting=quoting,
#    1094     cols=columns,
#    1095     index_label=index_label,
#    1096     mode=mode,
#    1097     chunksize=chunksize,
#    1098     quotechar=quotechar,
#    1099     date_format=date_format,
#    1100     doublequote=doublequote,
#    1101     escapechar=escapechar,
#    1102     storage_options=storage_options,
#    1103     formatter=self.fmt,
#    1104 )
#    1105 csv_formatter.save()
#    1107 if created_buffer:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\formats\csvs.py:87, in CSVFormatter.__init__(self, formatter, path_or_buf, sep, cols, index_label, mode, encoding, errors, compression, quoting, line_terminator, chunksize, quotechar, date_format, doublequote, escapechar, storage_options)
#      85 self.line_terminator = line_terminator or os.linesep
#      86 self.date_format = date_format
# ---> 87 self.cols = self._initialize_columns(cols)
#      88 self.chunksize = self._initialize_chunksize(chunksize)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\formats\csvs.py:159, in CSVFormatter._initialize_columns(self, cols)
#     156 # update columns to include possible multiplicity of dupes
#     157 # and make sure cols is just a list of labels
#     158 new_cols = self.obj.columns
# --> 159 return new_cols._format_native_types(**self._number_format)
#
# AttributeError: 'list' object has no attribute '_format_native_types'

# %%
#df = pd.read_csv('Master Sheets/Master User.csv', sep = ' ', header = None)
#df.columns
# Out:
# ['fleet',
#  'size',
#  'baseline_year',
#  'reporting_year',
#  'units',
#  'description',
#  'other']

# %%
#pd.DataFrame.columns = ['fleet', 'size', 'baseline_year', 'reporting_year', 'units', 'description', 'other']
#df.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python310\site-packages\IPython\core\formatters.py:707, in PlainTextFormatter.__call__(self, obj)
#     700 stream = StringIO()
#     701 printer = pretty.RepresentationPrinter(stream, self.verbose,
#     702     self.max_width, self.newline,
#     703     max_seq_length=self.max_seq_length,
#     704     singleton_pprinters=self.singleton_printers,
#     705     type_pprinters=self.type_printers,
#     706     deferred_pprinters=self.deferred_printers)
# --> 707 printer.pretty(obj)
#     708 printer.flush()
#     709 return stream.getvalue()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\IPython\lib\pretty.py:410, in RepresentationPrinter.pretty(self, obj)
#     407                         return meth(obj, self, cycle)
#     408                 if cls is not object \
#     409                         and callable(cls.__dict__.get('__repr__')):
# --> 410                     return _repr_pprint(obj, self, cycle)
#     412     return _default_pprint(obj, self, cycle)
#     413 finally:
#
# File ~\AppData\Roaming\Python\Python310\site-packages\IPython\lib\pretty.py:778, in _repr_pprint(obj, p, cycle)
#     776 """A pprint that just redirects to the normal repr function."""
#     777 # Find newlines and replace them with p.break_()
# --> 778 output = repr(obj)
#     779 lines = output.splitlines()
#     780 with p.group():
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:995, in DataFrame.__repr__(self)
#     993 else:
#     994     width = None
# --> 995 self.to_string(
#     996     buf=buf,
#     997     max_rows=max_rows,
#     998     min_rows=min_rows,
#     999     max_cols=max_cols,
#    1000     line_width=width,
#    1001     max_colwidth=max_colwidth,
#    1002     show_dimensions=show_dimensions,
#    1003 )
#    1005 return buf.getvalue()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:1131, in DataFrame.to_string(self, buf, columns, col_space, header, index, na_rep, formatters, float_format, sparsify, index_names, justify, max_rows, min_rows, max_cols, show_dimensions, decimal, line_width, max_colwidth, encoding)
#    1112 with option_context("display.max_colwidth", max_colwidth):
#    1113     formatter = fmt.DataFrameFormatter(
#    1114         self,
#    1115         columns=columns,
#    (...)
#    1129         decimal=decimal,
#    1130     )
# -> 1131     return fmt.DataFrameRenderer(formatter).to_string(
#    1132         buf=buf,
#    1133         encoding=encoding,
#    1134         line_width=line_width,
#    1135     )
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\formats\format.py:1053, in DataFrameRenderer.to_string(self, buf, encoding, line_width)
#    1050 from pandas.io.formats.string import StringFormatter
#    1052 string_formatter = StringFormatter(self.fmt, line_width=line_width)
# -> 1053 string = string_formatter.to_string()
#    1054 return save_to_buffer(string, buf=buf, encoding=encoding)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\formats\string.py:25, in StringFormatter.to_string(self)
#      24 def to_string(self) -> str:
# ---> 25     text = self._get_string_representation()
#      26     if self.fmt.should_show_dimensions:
#      27         text = "".join([text, self.fmt.dimensions_info])
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\formats\string.py:40, in StringFormatter._get_string_representation(self)
#      37 if self.fmt.frame.empty:
#      38     return self._empty_info_line
# ---> 40 strcols = self._get_strcols()
#      42 if self.line_width is None:
#      43     # no need to wrap around just print the whole frame
#      44     return self.adj.adjoin(1, *strcols)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\formats\string.py:31, in StringFormatter._get_strcols(self)
#      30 def _get_strcols(self) -> list[list[str]]:
# ---> 31     strcols = self.fmt.get_strcols()
#      32     if self.fmt.is_truncated:
#      33         strcols = self._insert_dot_separators(strcols)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\formats\format.py:540, in DataFrameFormatter.get_strcols(self)
#     536 def get_strcols(self) -> list[list[str]]:
#     537     """
#     538     Render a DataFrame to a list of columns (as lists of strings).
#     539     """
# --> 540     strcols = self._get_strcols_without_index()
#     542     if self.index:
#     543         str_index = self._get_formatted_index(self.tr_frame)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\formats\format.py:793, in DataFrameFormatter._get_strcols_without_index(self)
#     791     str_columns = [[label] for label in self.header]
#     792 else:
# --> 793     str_columns = self._get_formatted_column_labels(self.tr_frame)
#     795 if self.show_row_idx_names:
#     796     for x in str_columns:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\formats\format.py:871, in DataFrameFormatter._get_formatted_column_labels(self, frame)
#     869     str_columns = [list(x) for x in zip(*str_columns)]
#     870 else:
# --> 871     fmt_columns = columns.format()
#     872     dtypes = self.frame.dtypes
#     873     need_leadsp = dict(zip(fmt_columns, map(is_numeric_dtype, dtypes)))
#
# AttributeError: 'list' object has no attribute 'format'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python310\site-packages\IPython\core\formatters.py:343, in BaseFormatter.__call__(self, obj)
#     341     method = get_real_method(obj, self.print_method)
#     342     if method is not None:
# --> 343         return method()
#     344     return None
#     345 else:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:1047, in DataFrame._repr_html_(self)
#    1025     show_dimensions = get_option("display.show_dimensions")
#    1027     formatter = fmt.DataFrameFormatter(
#    1028         self,
#    1029         columns=None,
#    (...)
#    1045         decimal=".",
#    1046     )
# -> 1047     return fmt.DataFrameRenderer(formatter).to_html(notebook=True)
#    1048 else:
#    1049     return None
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\formats\format.py:1029, in DataFrameRenderer.to_html(self, buf, encoding, classes, notebook, border, table_id, render_links)
#    1020 Klass = NotebookFormatter if notebook else HTMLFormatter
#    1022 html_formatter = Klass(
#    1023     self.fmt,
#    1024     classes=classes,
#    (...)
#    1027     render_links=render_links,
#    1028 )
# -> 1029 string = html_formatter.to_string()
#    1030 return save_to_buffer(string, buf=buf, encoding=encoding)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\formats\html.py:72, in HTMLFormatter.to_string(self)
#      71 def to_string(self) -> str:
# ---> 72     lines = self.render()
#      73     if any(isinstance(x, str) for x in lines):
#      74         lines = [str(x) for x in lines]
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\formats\html.py:621, in NotebookFormatter.render(self)
#     619 self.write("<div>")
#     620 self.write_style()
# --> 621 super().render()
#     622 self.write("</div>")
#     623 return self.elements
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\formats\html.py:78, in HTMLFormatter.render(self)
#      77 def render(self) -> list[str]:
# ---> 78     self._write_table()
#      80     if self.should_show_dimensions:
#      81         by = chr(215)  # ×
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\formats\html.py:246, in HTMLFormatter._write_table(self, indent)
#     240 self.write(
#     241     f'<table border="{self.border}" class="{" ".join(_classes)}"{id_section}>',
#     242     indent,
#     243 )
#     245 if self.fmt.header or self.show_row_idx_names:
# --> 246     self._write_header(indent + self.indent_delta)
#     248 self._write_body(indent + self.indent_delta)
#     250 self.write("</table>", indent)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\formats\html.py:381, in HTMLFormatter._write_header(self, indent)
#     378 self.write("<thead>", indent)
#     380 if self.fmt.header:
# --> 381     self._write_col_header(indent + self.indent_delta)
#     383 if self.show_row_idx_names:
#     384     self._write_row_header(indent + self.indent_delta)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\formats\html.py:358, in HTMLFormatter._write_col_header(self, indent)
#     351 if self.fmt.index or self.show_col_idx_names:
#     352     # see gh-22747
#     353     # If to_html(index_names=False) do not show columns
#     354     # index names.
#     355     # TODO: Refactor to use _get_column_name_list from
#     356     # DataFrameFormatter class.
#     357     if self.fmt.show_index_names:
# --> 358         row.append(self.columns.name or "")
#     359     else:
#     360         row.append("")
#
# AttributeError: 'list' object has no attribute 'name'

# %%
#put column for fleet name
#add date column
#emissiosn factor: CO2 emitted per mile driven (can get from CARB or EMFAC)
#df = pd.read_csv('Master Sheets/Master BYD.csv', sep = ' ', header = None)
#df.head()
# Out:
#           0               1        2  3  4       5         6            7
# 0  Gasoline      Box Trucks  Group 1  1  0  5000.0  Baseline  Black Solid
# 1  Gasoline            Vans  Group 1  0  0     0.0  Baseline  Black Solid
# 2  Gasoline  Two-Axle Buses  Group 1  0  0     0.0  Baseline  Black Solid
# 3  Gasoline     Yard Trucks  Group 1  0  0     0.0  Baseline  Black Solid
# 4  Gasoline      Light-Duty  Group 1  0  0     0.0  Baseline  Black Solid

# %%
#tail pipe emissions since lifetime emissions requires figuring out how the electricity used to create vehicles was generated)
#df = pd.read_csv('Master Sheets/Master Fuel.csv', sep = ' ', header = None)
#df.head(20)
# Out:
#                                                 0      1     2              3  \
# 0                                        Gasoline    0.0     0        gallons
# 1                                          Diesel    0.0     0        gallons
# 2                                     Electricity    0.0     0            kWh
# 3                                  Light-duty BEV    0.0     0          miles
# 4                 Medium-duty BEV (Class 3-4-5-6)    0.0     0          miles
# 5                      Heavy-duty BEV (Class 7-8)    0.0     0          miles
# 6                                       Biodiesel    0.0  0.05     B5 gallons
# 7                                     Ethanol E85    0.0    No    E85 gallons
# 8                         Liquified Petroleum Gas    0.0     0    LPG gallons
# 9                          Compressed Natural Gas    0.0     0            DGE
# 10                          Liquified Natural Gas    0.0     0    LNG gallons
# 11  Liquified Natural Gas (Diesel Pilot Ignition)    0.0     0  LNG/D gallons
# 12                               Renewable Diesel    0.0   0.2   RD20 gallons
# 13                                      Fuel Cell    0.0     0      H gallons
# 14                                   Pure Ethanol    0.0     0   E100 gallons
# 15                                 Pure Biodiesel    0.0     0   B100 gallons
# 16                               Alternate Fuel 1    0.0     0              0
# 17                               Alternate Fuel 2    0.0     0              0
# 18                               Alternate Fuel 3    0.0     0              0
# 19                                       Gasoline  500.0     0        gallons
#
#             4
# 0    Baseline
# 1    Baseline
# 2    Baseline
# 3    Baseline
# 4    Baseline
# 5    Baseline
# 6    Baseline
# 7    Baseline
# 8    Baseline
# 9    Baseline
# 10   Baseline
# 11   Baseline
# 12   Baseline
# 13   Baseline
# 14   Baseline
# 15   Baseline
# 16   Baseline
# 17   Baseline
# 18   Baseline
# 19  Reporting
